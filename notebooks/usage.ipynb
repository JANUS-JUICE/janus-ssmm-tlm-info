# %% [markdown]
# # Example of usage
#
# Only `ssm_file_info` is expected to be part of the public interface of this package. Please do not use any other component as might change.

# %% [markdown]
# Just a reminder of JANUS science telemetry package structure:
#
# ![image.png](attachment:image.png)

# %%
from janus_ssmm_tlm_info import ssm_file_info

# %% [markdown]
# Remember to load the spice kernels needed. The tool expect they already loaded.
#
# They are only used to resolve coarse/fine time into UTC time.

# %%
import spiceypy
# point this to the right path...
spiceypy.furnsh("/home/luca/data/JUICE.git/kernels/mk/juice_ops_local.tm")

# %%
# change to an existing JANUS ssmm image, this one is a 10-packages subset of one.
ssm_file_info(
    "../tests/data/test.bin"
)
# Out:
# {'file_name': 'test.bin',
#  'npacks': 10,
#  'apids': [668],
#  'sessions': [777503922],
#  'start_time': '2024-08-20T21:35:16.760451+00:00',
#  'end_time': '2024-08-20T21:35:16.760451+00:00'}
