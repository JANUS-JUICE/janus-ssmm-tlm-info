# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sys
sys.path.insert(0 , '../')

from tests.data import get_simple_ssmm, joined

# the library expects spice kernels to be already laoded
import spiceypy

spiceypy.furnsh("/home/luca/data/JUICE.git/kernels/mk/juice_ops_local.tm")

# %%
from janus_ssmm_tlm_info.janus_pkt import SSMM
from janus_ssmm_tlm_info.time import coarse_fine_to_datetime

from construct import Compiled

# %%
joined()
# Out:
# PosixPath('/home/luca/data/Code/juice-janus-code/janus-ssmm-tlm-info.git/notebooks/../tests/data/JAN2_4700000AB_joined')

# %%
got = SSMM.parse_file(joined())

# %%
joined()
# Out:
# PosixPath('/home/luca/data/Code/juice-janus-code/janus-ssmm-tlm-info.git/notebooks/../tests/data/JAN2_4700000AB_joined')

# %%
small = got.packets[:10]

# %%
SSMM.packets.build_file(small, 'test.bin')

# %%
import numpy as np
np.unique(got.search_all('SESSION_ID'))
# Out:
# array([777503922, 777504999])

# %%
comp = SSMM.compile(filename='compiled.py')

# %%
got2 = comp.parse_file(get_simple_ssmm())

# %%
for i in got.packets:
    fine = i.data_field_header['FINE_TIME']
    coarse = i.data_field_header['COARSE_TIME']
    t = coarse_fine_to_datetime(coarse, fine)
    print(t)
# Out:
# 2024-08-20 21:35:16.760451+00:00
# 2024-08-20 21:35:16.760451+00:00
# 2024-08-20 21:35:16.760451+00:00
# 2024-08-20 21:35:16.760451+00:00
# 2024-08-20 21:35:16.760451+00:00
# 2024-08-20 21:35:16.760451+00:00
# 2024-08-20 21:35:16.760451+00:00
# 2024-08-20 21:35:16.760451+00:00
# 2024-08-20 21:35:16.760451+00:00
# 2024-08-20 21:35:16.760451+00:00
# 2024-08-20 21:35:16.760451+00:00
# 2024-08-20 21:35:16.760451+00:00
# 2024-08-20 21:35:16.760451+00:00
# 2024-08-20 21:35:16.760451+00:00
# 2024-08-20 21:35:16.760451+00:00
# 2024-08-20 21:35:16.760451+00:00
# 2024-08-20 21:35:16.760451+00:00
# 2024-08-20 21:35:16.760451+00:00
# 2024-08-20 21:35:16.760451+00:00
# 2024-08-20 21:35:16.760451+00:00
# 2024-08-20 21:35:16.760451+00:00
# 2024-08-20 21:35:16.760451+00:00
# 2024-08-20 21:35:16.760451+00:00
# 2024-08-20 21:35:16.760451+00:00
# 2024-08-20 21:35:16.760451+00:00
# 2024-08-20 21:35:16.760451+00:00
# 2024-08-20 21:35:16.760451+00:00
# 2024-08-20 21:35:16.760451+00:00
# ...

# %%
got.search_all('COARSE_TIME')
# Out:
# [777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
#  777504925,
# ...
